# %%
#准备matplotlib显示，opencv所有的图像显示用matplotlib，其他的功能都用opencv自己的
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %%
img = cv.imread('/home/jiacai_chen/Pictures/2.png',cv.IMREAD_ANYCOLOR) # cv.IMREAD_ANYCOLOR用彩色模式加载

# %%
#opencv的图像显示，转换成matplotlib的数据，用matplotlib去显示。
cv_rgb = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #opencv的颜色3通道的排列顺序是BGR，matplotlib的是RGB，显示的时候数据要转换顺序
cv_gray= cv.cvtColor(img,cv.COLOR_BGR2GRAY)  #彩色转换为黑白
#plt.imshow(cv_rgb)  #显示彩色图像
#plt.imshow(cv_gray,'gray')  #显示黑白图像

#cv.imwrite('messigray.png',cv_gray)#保存灰度图
#cv.imwrite('messigray.png',img) #保存彩色图

# %%
plt.imshow(cv_rgb)

# %%
cv.imwrite('/home/jiacai_chen/Pictures/我的桌面.jpg',img)
# Out:
# True
